# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt,gc,os
from tqdm.auto import tqdm
import itertools
tqdm.pandas()
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

#print('RAPIDS version',cudf.__version__)

# %%
GPU = True
try:
    import cupy, cudf
except ImportError:
    GPU = False

# %%
# VERSION NAME FOR SAVED MODEL FILES
VER = 1

# TRAIN RANDOM SEED
SEED = 42

# FILL NAN VALUE
NAN_VALUE = -127 # will fit in int8

# FOLDS PER MODEL
FOLDS = 5

GPU =True

TRAIN_NUM_PARTS = 2
TEST_SECTIONS = 2
TEST_NUM_PARTS = 2

# %%
TRAIN_PATH = '../input/amexfeatureengineering/770_FE_train.feather'
train = pd.read_feather(TRAIN_PATH)

# %%
train.sample()
# Out:
#                 customer_ID  B_30_nunique  B_38_last  B_38_nunique  \
# 190839 -1551089096557598217             1          3             2
#
#         D_114_last  D_117_last  D_120_last  D_120_nunique  D_66_last  \
# 190839           1           2           1              2          0
#
#         D_66_nunique  ...  D_53_last_mean_diff  B_28_last_mean_diff  \
# 190839             1  ...            -0.002375              0.01181
#
#         S_22_last_mean_diff  B_3_last_mean_diff  D_56_last_mean_diff  \
# 190839             0.013428            0.021942                  0.0
#
#         D_130_last_mean_diff  S_7_last_mean_diff  total_data_count  \
# 190839              0.000619            0.032318            2285.0
#
#         total_data_last  target
# 190839            174.0       0
#
# [1 rows x 772 columns]

# %%
# FEATURES
FEATURES = train.columns[1:-1]
print(f'There are {len(FEATURES)} features!')
# Out:
# There are 770 features!

# %%
# LOAD XGB LIBRARY
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb

# XGB MODEL PARAMETERS
xgb_params = {
            'objective': 'binary:logitraw', 
            'tree_method': 'gpu_hist',
            'predictor':'gpu_predictor',
            'max_depth': 7,    
            'subsample':0.9,   
            'colsample_bytree': 0.25,  
            'gamma':1.5,        
            'min_child_weight':8, 
            'lambda': 10,   
            'random_state':42,
            'eval_metric':'auc',
            'num_parallel_tree':1,
    }

# %%
# NEEDED WITH DeviceQuantileDMatrix BELOW
class IterLoadForDMatrix(xgb.core.DataIter):
    def __init__(self, df=None, features=None, target=None, batch_size=256*1024):
        self.features = features
        self.target = target
        self.df = df
        self.it = 0 # set iterator to 0
        self.batch_size = batch_size
        self.batches = int( np.ceil( len(df) / self.batch_size ) )
        super().__init__()

    def reset(self):
        '''Reset the iterator'''
        self.it = 0

    def next(self, input_data):
        '''Yield next batch of data.'''
        if self.it == self.batches:
            return 0 # Return 0 when there's no more batch.
        
        a = self.it * self.batch_size
        b = min( (self.it + 1) * self.batch_size, len(self.df) )
        dt = cudf.DataFrame(self.df.iloc[a:b])
        input_data(data=dt[self.features], label=dt[self.target]) #, weight=dt['weight'])
        self.it += 1
        return 1

# %%
# https://www.kaggle.com/kyakovlev
# https://www.kaggle.com/competitions/amex-default-prediction/discussion/327534
def amex_metric_mod(y_true, y_pred):

    labels     = np.transpose(np.array([y_true, y_pred]))
    labels     = labels[labels[:, 1].argsort()[::-1]]
    weights    = np.where(labels[:,0]==0, 20, 1)
    cut_vals   = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four   = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])

    gini = [0,0]
    for i in [1,0]:
        labels         = np.transpose(np.array([y_true, y_pred]))
        labels         = labels[labels[:, i].argsort()[::-1]]
        weight         = np.where(labels[:,0]==0, 20, 1)
        weight_random  = np.cumsum(weight / np.sum(weight))
        total_pos      = np.sum(labels[:, 0] *  weight)
        cum_pos_found  = np.cumsum(labels[:, 0] * weight)
        lorentz        = cum_pos_found / total_pos
        gini[i]        = np.sum((lorentz - weight_random) * weight)

    return 0.5 * (gini[1]/gini[0] + top_four)

# %%
def xgb_amex(y_pred, y_true):
    return 'amex', amex_metric_np(y_pred,y_true.get_label())
def lgb_amex_metric(y_pred, y_true):
    return 'amex', amex_metric_np(y_pred,y_true.get_label()), True

# code by @https://www.kaggle.com/yunchonggan
# https://www.kaggle.com/competitions/amex-default-prediction/discussion/328020
def amex_metric_np(preds: np.ndarray, target: np.ndarray) -> float:
    n_pos = np.sum(target)
    n_neg = target.shape[0] - n_pos

    indices = np.argsort(preds)[::-1]
    preds, target = preds[indices], target[indices]

    weight = 20.0 - target * 19.0
    cum_norm_weight = (weight * (1 / weight.sum())).cumsum()
    four_pct_mask = cum_norm_weight <= 0.04
    d = np.sum(target[four_pct_mask]) / n_pos

    lorentz = (target * (1 / n_pos)).cumsum()
    gini = ((lorentz - cum_norm_weight) * weight).sum()

    gini_max = 10 * n_neg * (1 - 19 / (n_pos + 20 * n_neg))

    g = gini / gini_max
    return 0.5 * (g + d)

# %%
import pandas as pd
def amex_metric(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:

    def top_four_percent_captured(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:
        df = (pd.concat([y_true, y_pred], axis='columns')
              .sort_values('prediction', ascending=False))
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        four_pct_cutoff = int(0.04 * df['weight'].sum())
        df['weight_cumsum'] = df['weight'].cumsum()
        df_cutoff = df.loc[df['weight_cumsum'] <= four_pct_cutoff]
        return (df_cutoff['target'] == 1).sum() / (df['target'] == 1).sum()
        
    def weighted_gini(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:
        df = (pd.concat([y_true, y_pred], axis='columns')
              .sort_values('prediction', ascending=False))
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        df['random'] = (df['weight'] / df['weight'].sum()).cumsum()
        total_pos = (df['target'] * df['weight']).sum()
        df['cum_pos_found'] = (df['target'] * df['weight']).cumsum()
        df['lorentz'] = df['cum_pos_found'] / total_pos
        df['gini'] = (df['lorentz'] - df['random']) * df['weight']
        return df['gini'].sum()

    def normalized_weighted_gini(y_true: pd.DataFrame, y_pred: pd.DataFrame) -> float:
        y_true_pred = y_true.rename(columns={'target': 'prediction'})
        return weighted_gini(y_true, y_pred) / weighted_gini(y_true, y_true_pred)

    g = normalized_weighted_gini(y_true, y_pred)
    d = top_four_percent_captured(y_true, y_pred)

    return 0.5 * (g + d)

# %%
importances = []
oof = []
#train = train.to_pandas() # free GPU memory
TRAIN_SUBSAMPLE = 1.0
gc.collect() 

# XGB MODEL PARAMETERS
BASE_LEARNING_RATE = 0.015
PYRAMID_W = [0.5, 2/3, 0.75, 0.875, 1, 0]

skf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=SEED)
for fold,(train_idx, valid_idx) in enumerate(skf.split(
            train, train.target )):
    
    # TRAIN WITH SUBSAMPLE OF TRAIN FOLD DATA
    if TRAIN_SUBSAMPLE<1.0:
        np.random.seed(SEED)
        train_idx = np.random.choice(train_idx, 
                       int(len(train_idx)*TRAIN_SUBSAMPLE), replace=False)
        np.random.seed(None)    
    
    print('#'*25)
    print('### Fold',fold+1)
    print('### Train size',len(train_idx),'Valid size',len(valid_idx))
    print(f'### Training with {int(TRAIN_SUBSAMPLE*100)}% fold data...')
    print('#'*25)
    
    # TRAIN, VALID, TEST FOR FOLD K
    Xy_train = IterLoadForDMatrix(train.loc[train_idx], FEATURES, 'target')
    X_valid = train.loc[valid_idx, FEATURES]
    y_valid = train.loc[valid_idx, 'target']
    

    dtrain = xgb.DeviceQuantileDMatrix(Xy_train, max_bin=256)
    dvalid = xgb.DMatrix(data=X_valid, label=y_valid)
    
    # TRAIN MODEL FOLD K
    # PYRAMID: Smoothly go from diverse forest of early trees into focused boosted trees correcting residuals.
    #   final layer must have w==0
    #   columns:    forest|boost|adj_eta|w
    pyramid_layers = [( 40,  10,  1.56,  0.5),
                          (  8,  50,  1.3,   2/3),
                          (  1, 400,  1.25,  0.75),
                          (  1, 400,  1.125, 0.875),
                          (  1,1200,  1.0,   1),
                          (  1,5200,  0.5,   0)]
    assert(PYRAMID_W == [layer[-1] for layer in pyramid_layers])
    
    for (layer, (n_trees, n_rounds, adj_learning, w)) in enumerate(pyramid_layers):
            ## Load the manual parameters from the pyramid layer
            xgb_params['num_parallel_tree'] = n_trees
            xgb_params['learning_rate'] = n_trees*adj_learning*BASE_LEARNING_RATE
            
            ## No early stopping except on final round. This is important since the weighting causes the model to go backwards for a time at the start of the next layer.
            early_stop = None
            if w == 0:
                early_stop = 1800        
    
            model = xgb.train(xgb_params, 
                        dtrain=dtrain,
                        evals=[(dtrain,'train'),(dvalid,'valid')],
                        num_boost_round=n_rounds,
                        early_stopping_rounds=early_stop,
                        custom_metric=xgb_amex,
                        maximize=True,
                        verbose_eval=200//n_trees)
        
            model.save_model(f'XGB_v{VER}_fold{fold}_layer{layer}.xgb')
            
            ## predict to load the predictions on the next model layer
            ## Don't set base margin on final layer. w = 0 is used as an encoded way to skip this step.
            if (w != 0):
                ptrain = model.predict(dtrain, output_margin=True)
                pvalid = model.predict(dvalid, output_margin=True)
                
            ## reduce the impact of all model layers so far by w. This should be another way to reduce over-specialization, without the computational cost of DART
                if (w < 1.0):
                    ptrain = ptrain * w
                    pvalid = pvalid * w  
            
            ## This set_base_margin on the DMatrix data is what informs the next layer of the prior training.
            ## See code example from official demos: https://github.com/dmlc/xgboost/blob/master/demo/guide-python/boost_from_prediction.py
                dtrain.set_base_margin(ptrain)
                dvalid.set_base_margin(pvalid)
            
                del model, ptrain, pvalid
                gc.collect()
            
    del dtrain
    _ = gc.collect()        

            
    # INFER OOF FOLD K
    oof_preds = model.predict(dvalid)
    acc = amex_metric_mod(y_valid.values, oof_preds)
    print('Kaggle Metric =',acc,'\n')
    
    # SAVE OOF
    df = train.loc[valid_idx, ['customer_ID','target'] ].copy()
    df['oof_pred'] = oof_preds
    oof.append( df )
    
    del Xy_train, df
    del X_valid, y_valid, dvalid
    _ = gc.collect()
    
print('#'*25)
oof = pd.concat(oof,axis=0,ignore_index=True).set_index('customer_ID')
acc = amex_metric_mod(oof.target.values, oof.oof_pred.values)
print('OVERALL CV Kaggle Metric =',acc)
# Out:
# #########################
# ### Fold 1
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.95201	train-amex:0.75805	valid-auc:0.95011	valid-amex:0.74701
# [5]	train-auc:0.96339	train-amex:0.79929	valid-auc:0.95867	valid-amex:0.77834
# [9]	train-auc:0.96728	train-amex:0.81756	valid-auc:0.96033	valid-amex:0.78591
# [0]	train-auc:0.96692	train-amex:0.81583	valid-auc:0.96018	valid-amex:0.78462
# [25]	train-auc:0.96744	train-amex:0.81787	valid-auc:0.96033	valid-amex:0.78496
# [49]	train-auc:0.97014	train-amex:0.83132	valid-auc:0.96123	valid-amex:0.78895
# [0]	train-auc:0.97011	train-amex:0.83119	valid-auc:0.96122	valid-amex:0.78871
# [200]	train-auc:0.97033	train-amex:0.83201	valid-auc:0.96115	valid-amex:0.78831
# [399]	train-auc:0.97246	train-amex:0.84318	valid-auc:0.96168	valid-amex:0.79035
# [0]	train-auc:0.97244	train-amex:0.84307	valid-auc:0.96167	valid-amex:0.79015
# [200]	train-auc:0.97257	train-amex:0.84344	valid-auc:0.96161	valid-amex:0.79014
# [399]	train-auc:0.97418	train-amex:0.85235	valid-auc:0.96194	valid-amex:0.79099
# [0]	train-auc:0.97418	train-amex:0.85221	valid-auc:0.96194	valid-amex:0.79100
# [200]	train-auc:0.97491	train-amex:0.85598	valid-auc:0.96203	valid-amex:0.79160
# [400]	train-auc:0.97609	train-amex:0.86255	valid-auc:0.96221	valid-amex:0.79231
# [600]	train-auc:0.97725	train-amex:0.86877	valid-auc:0.96233	valid-amex:0.79273
# [800]	train-auc:0.97840	train-amex:0.87501	valid-auc:0.96244	valid-amex:0.79390
# [1000]	train-auc:0.97942	train-amex:0.88041	valid-auc:0.96251	valid-amex:0.79429
# [1199]	train-auc:0.98042	train-amex:0.88595	valid-auc:0.96257	valid-amex:0.79477
# [0]	train-auc:0.98042	train-amex:0.88592	valid-auc:0.96257	valid-amex:0.79475
# [200]	train-auc:0.98089	train-amex:0.88865	valid-auc:0.96259	valid-amex:0.79458
# [400]	train-auc:0.98137	train-amex:0.89108	valid-auc:0.96261	valid-amex:0.79492
# [600]	train-auc:0.98183	train-amex:0.89367	valid-auc:0.96263	valid-amex:0.79479
# [800]	train-auc:0.98229	train-amex:0.89603	valid-auc:0.96264	valid-amex:0.79447
# [1000]	train-auc:0.98271	train-amex:0.89834	valid-auc:0.96266	valid-amex:0.79495
# [1200]	train-auc:0.98314	train-amex:0.90085	valid-auc:0.96268	valid-amex:0.79495
# [1400]	train-auc:0.98358	train-amex:0.90306	valid-auc:0.96269	valid-amex:0.79517
# [1600]	train-auc:0.98403	train-amex:0.90576	valid-auc:0.96270	valid-amex:0.79511
# [1800]	train-auc:0.98447	train-amex:0.90804	valid-auc:0.96271	valid-amex:0.79538
# [2000]	train-auc:0.98486	train-amex:0.91044	valid-auc:0.96272	valid-amex:0.79520
# [2200]	train-auc:0.98526	train-amex:0.91244	valid-auc:0.96273	valid-amex:0.79521
# [2400]	train-auc:0.98564	train-amex:0.91463	valid-auc:0.96274	valid-amex:0.79562
# [2600]	train-auc:0.98603	train-amex:0.91691	valid-auc:0.96275	valid-amex:0.79548
# [2800]	train-auc:0.98642	train-amex:0.91900	valid-auc:0.96275	valid-amex:0.79563
# [3000]	train-auc:0.98679	train-amex:0.92126	valid-auc:0.96275	valid-amex:0.79538
# [3200]	train-auc:0.98716	train-amex:0.92346	valid-auc:0.96275	valid-amex:0.79555
# [3400]	train-auc:0.98751	train-amex:0.92532	valid-auc:0.96275	valid-amex:0.79559
# [3600]	train-auc:0.98786	train-amex:0.92719	valid-auc:0.96276	valid-amex:0.79545
# [3800]	train-auc:0.98820	train-amex:0.92924	valid-auc:0.96276	valid-amex:0.79545
# [4000]	train-auc:0.98855	train-amex:0.93120	valid-auc:0.96277	valid-amex:0.79512
# [4200]	train-auc:0.98886	train-amex:0.93318	valid-auc:0.96278	valid-amex:0.79473
# [4400]	train-auc:0.98921	train-amex:0.93524	valid-auc:0.96277	valid-amex:0.79487
# [4576]	train-auc:0.98949	train-amex:0.93697	valid-auc:0.96278	valid-amex:0.79485
# Kaggle Metric = 0.7946164660261545
#
# #########################
# ### Fold 2
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.95205	train-amex:0.75659	valid-auc:0.94997	valid-amex:0.75202
# [5]	train-auc:0.96343	train-amex:0.79873	valid-auc:0.95850	valid-amex:0.78198
# [9]	train-auc:0.96752	train-amex:0.81793	valid-auc:0.96019	valid-amex:0.78865
# [0]	train-auc:0.96714	train-amex:0.81608	valid-auc:0.96000	valid-amex:0.78833
# [25]	train-auc:0.96755	train-amex:0.81756	valid-auc:0.96009	valid-amex:0.78948
# [49]	train-auc:0.97033	train-amex:0.83166	valid-auc:0.96101	valid-amex:0.79170
# [0]	train-auc:0.97030	train-amex:0.83149	valid-auc:0.96100	valid-amex:0.79158
# [200]	train-auc:0.97053	train-amex:0.83233	valid-auc:0.96091	valid-amex:0.79236
# [399]	train-auc:0.97271	train-amex:0.84406	valid-auc:0.96147	valid-amex:0.79340
# [0]	train-auc:0.97269	train-amex:0.84386	valid-auc:0.96146	valid-amex:0.79341
# [200]	train-auc:0.97279	train-amex:0.84442	valid-auc:0.96137	valid-amex:0.79315
# [399]	train-auc:0.97443	train-amex:0.85322	valid-auc:0.96173	valid-amex:0.79463
# [0]	train-auc:0.97443	train-amex:0.85313	valid-auc:0.96173	valid-amex:0.79467
# [200]	train-auc:0.97512	train-amex:0.85680	valid-auc:0.96183	valid-amex:0.79499
# [400]	train-auc:0.97635	train-amex:0.86334	valid-auc:0.96203	valid-amex:0.79571
# [600]	train-auc:0.97760	train-amex:0.87026	valid-auc:0.96217	valid-amex:0.79534
# [800]	train-auc:0.97878	train-amex:0.87695	valid-auc:0.96226	valid-amex:0.79563
# [1000]	train-auc:0.97987	train-amex:0.88302	valid-auc:0.96234	valid-amex:0.79562
# [1199]	train-auc:0.98092	train-amex:0.88884	valid-auc:0.96241	valid-amex:0.79634
# [0]	train-auc:0.98093	train-amex:0.88891	valid-auc:0.96241	valid-amex:0.79631
# [200]	train-auc:0.98143	train-amex:0.89173	valid-auc:0.96244	valid-amex:0.79668
# [400]	train-auc:0.98195	train-amex:0.89448	valid-auc:0.96247	valid-amex:0.79631
# [600]	train-auc:0.98240	train-amex:0.89676	valid-auc:0.96249	valid-amex:0.79634
# [800]	train-auc:0.98288	train-amex:0.89958	valid-auc:0.96251	valid-amex:0.79681
# [1000]	train-auc:0.98333	train-amex:0.90206	valid-auc:0.96253	valid-amex:0.79688
# [1200]	train-auc:0.98378	train-amex:0.90444	valid-auc:0.96255	valid-amex:0.79709
# [1400]	train-auc:0.98421	train-amex:0.90697	valid-auc:0.96257	valid-amex:0.79699
# [1600]	train-auc:0.98464	train-amex:0.90949	valid-auc:0.96259	valid-amex:0.79766
# [1800]	train-auc:0.98506	train-amex:0.91168	valid-auc:0.96261	valid-amex:0.79740
# [2000]	train-auc:0.98547	train-amex:0.91401	valid-auc:0.96262	valid-amex:0.79703
# [2200]	train-auc:0.98587	train-amex:0.91607	valid-auc:0.96263	valid-amex:0.79778
# [2400]	train-auc:0.98628	train-amex:0.91822	valid-auc:0.96264	valid-amex:0.79798
# [2600]	train-auc:0.98666	train-amex:0.92048	valid-auc:0.96265	valid-amex:0.79808
# [2800]	train-auc:0.98703	train-amex:0.92248	valid-auc:0.96266	valid-amex:0.79815
# [3000]	train-auc:0.98740	train-amex:0.92469	valid-auc:0.96267	valid-amex:0.79799
# [3200]	train-auc:0.98776	train-amex:0.92686	valid-auc:0.96268	valid-amex:0.79824
# [3400]	train-auc:0.98812	train-amex:0.92892	valid-auc:0.96268	valid-amex:0.79816
# [3600]	train-auc:0.98847	train-amex:0.93105	valid-auc:0.96269	valid-amex:0.79839
# [3800]	train-auc:0.98881	train-amex:0.93309	valid-auc:0.96269	valid-amex:0.79829
# [4000]	train-auc:0.98914	train-amex:0.93518	valid-auc:0.96269	valid-amex:0.79877
# [4200]	train-auc:0.98945	train-amex:0.93705	valid-auc:0.96270	valid-amex:0.79865
# [4400]	train-auc:0.98978	train-amex:0.93891	valid-auc:0.96270	valid-amex:0.79859
# [4600]	train-auc:0.99010	train-amex:0.94083	valid-auc:0.96271	valid-amex:0.79868
# [4800]	train-auc:0.99039	train-amex:0.94236	valid-auc:0.96271	valid-amex:0.79828
# [5000]	train-auc:0.99069	train-amex:0.94418	valid-auc:0.96271	valid-amex:0.79820
# [5199]	train-auc:0.99098	train-amex:0.94590	valid-auc:0.96271	valid-amex:0.79803
# Kaggle Metric = 0.7977889406852082
#
# #########################
# ### Fold 3
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.95208	train-amex:0.75678	valid-auc:0.95006	valid-amex:0.74968
# [5]	train-auc:0.96341	train-amex:0.79864	valid-auc:0.95872	valid-amex:0.78150
# [9]	train-auc:0.96747	train-amex:0.81774	valid-auc:0.96043	valid-amex:0.78927
# [0]	train-auc:0.96708	train-amex:0.81574	valid-auc:0.96024	valid-amex:0.78782
# [25]	train-auc:0.96754	train-amex:0.81790	valid-auc:0.96034	valid-amex:0.78815
# [49]	train-auc:0.97031	train-amex:0.83181	valid-auc:0.96126	valid-amex:0.79193
# [0]	train-auc:0.97027	train-amex:0.83175	valid-auc:0.96125	valid-amex:0.79227
# [200]	train-auc:0.97045	train-amex:0.83262	valid-auc:0.96120	valid-amex:0.79244
# [399]	train-auc:0.97261	train-amex:0.84396	valid-auc:0.96174	valid-amex:0.79401
# [0]	train-auc:0.97259	train-amex:0.84378	valid-auc:0.96174	valid-amex:0.79386
# [200]	train-auc:0.97270	train-amex:0.84416	valid-auc:0.96165	valid-amex:0.79417
# [399]	train-auc:0.97432	train-amex:0.85297	valid-auc:0.96198	valid-amex:0.79528
# [0]	train-auc:0.97431	train-amex:0.85294	valid-auc:0.96198	valid-amex:0.79530
# [200]	train-auc:0.97504	train-amex:0.85676	valid-auc:0.96205	valid-amex:0.79590
# [400]	train-auc:0.97624	train-amex:0.86334	valid-auc:0.96222	valid-amex:0.79649
# [600]	train-auc:0.97740	train-amex:0.86944	valid-auc:0.96235	valid-amex:0.79658
# [800]	train-auc:0.97854	train-amex:0.87603	valid-auc:0.96244	valid-amex:0.79685
# [1000]	train-auc:0.97962	train-amex:0.88170	valid-auc:0.96250	valid-amex:0.79738
# [1199]	train-auc:0.98064	train-amex:0.88733	valid-auc:0.96257	valid-amex:0.79738
# [0]	train-auc:0.98064	train-amex:0.88730	valid-auc:0.96257	valid-amex:0.79740
# [200]	train-auc:0.98112	train-amex:0.88975	valid-auc:0.96260	valid-amex:0.79747
# [400]	train-auc:0.98160	train-amex:0.89231	valid-auc:0.96262	valid-amex:0.79735
# [600]	train-auc:0.98206	train-amex:0.89471	valid-auc:0.96264	valid-amex:0.79748
# [800]	train-auc:0.98251	train-amex:0.89745	valid-auc:0.96266	valid-amex:0.79752
# [1000]	train-auc:0.98297	train-amex:0.89979	valid-auc:0.96268	valid-amex:0.79709
# [1200]	train-auc:0.98343	train-amex:0.90245	valid-auc:0.96270	valid-amex:0.79770
# [1400]	train-auc:0.98386	train-amex:0.90464	valid-auc:0.96271	valid-amex:0.79770
# [1600]	train-auc:0.98429	train-amex:0.90697	valid-auc:0.96273	valid-amex:0.79773
# [1800]	train-auc:0.98471	train-amex:0.90938	valid-auc:0.96274	valid-amex:0.79727
# [2000]	train-auc:0.98512	train-amex:0.91166	valid-auc:0.96275	valid-amex:0.79741
# [2200]	train-auc:0.98550	train-amex:0.91390	valid-auc:0.96275	valid-amex:0.79721
# [2400]	train-auc:0.98588	train-amex:0.91595	valid-auc:0.96276	valid-amex:0.79734
# [2600]	train-auc:0.98626	train-amex:0.91831	valid-auc:0.96276	valid-amex:0.79728
# [2800]	train-auc:0.98664	train-amex:0.92032	valid-auc:0.96276	valid-amex:0.79705
# [3000]	train-auc:0.98699	train-amex:0.92241	valid-auc:0.96277	valid-amex:0.79696
# [3200]	train-auc:0.98738	train-amex:0.92484	valid-auc:0.96278	valid-amex:0.79749
# [3214]	train-auc:0.98741	train-amex:0.92495	valid-auc:0.96278	valid-amex:0.79736
# Kaggle Metric = 0.7971234770401678
#
# #########################
# ### Fold 4
# ### Train size 367131 Valid size 91782
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.95219	train-amex:0.75779	valid-auc:0.95016	valid-amex:0.75163
# [5]	train-auc:0.96361	train-amex:0.79935	valid-auc:0.95824	valid-amex:0.78172
# [9]	train-auc:0.96758	train-amex:0.81771	valid-auc:0.95985	valid-amex:0.78708
# [0]	train-auc:0.96721	train-amex:0.81635	valid-auc:0.95974	valid-amex:0.78661
# [25]	train-auc:0.96767	train-amex:0.81832	valid-auc:0.95988	valid-amex:0.78744
# [49]	train-auc:0.97041	train-amex:0.83172	valid-auc:0.96075	valid-amex:0.79107
# [0]	train-auc:0.97038	train-amex:0.83167	valid-auc:0.96074	valid-amex:0.79091
# [200]	train-auc:0.97059	train-amex:0.83282	valid-auc:0.96068	valid-amex:0.79073
# [399]	train-auc:0.97273	train-amex:0.84375	valid-auc:0.96119	valid-amex:0.79338
# [0]	train-auc:0.97271	train-amex:0.84367	valid-auc:0.96118	valid-amex:0.79356
# [200]	train-auc:0.97284	train-amex:0.84410	valid-auc:0.96115	valid-amex:0.79256
# [399]	train-auc:0.97445	train-amex:0.85292	valid-auc:0.96146	valid-amex:0.79356
# [0]	train-auc:0.97444	train-amex:0.85287	valid-auc:0.96146	valid-amex:0.79365
# [200]	train-auc:0.97518	train-amex:0.85672	valid-auc:0.96155	valid-amex:0.79444
# [400]	train-auc:0.97638	train-amex:0.86319	valid-auc:0.96174	valid-amex:0.79519
# [600]	train-auc:0.97756	train-amex:0.86981	valid-auc:0.96189	valid-amex:0.79505
# [800]	train-auc:0.97868	train-amex:0.87567	valid-auc:0.96200	valid-amex:0.79516
# [1000]	train-auc:0.97980	train-amex:0.88199	valid-auc:0.96209	valid-amex:0.79596
# [1199]	train-auc:0.98081	train-amex:0.88741	valid-auc:0.96216	valid-amex:0.79593
# [0]	train-auc:0.98081	train-amex:0.88740	valid-auc:0.96216	valid-amex:0.79593
# [200]	train-auc:0.98133	train-amex:0.89028	valid-auc:0.96219	valid-amex:0.79579
# [400]	train-auc:0.98181	train-amex:0.89291	valid-auc:0.96222	valid-amex:0.79585
# [600]	train-auc:0.98229	train-amex:0.89570	valid-auc:0.96225	valid-amex:0.79574
# [800]	train-auc:0.98274	train-amex:0.89830	valid-auc:0.96227	valid-amex:0.79629
# [1000]	train-auc:0.98319	train-amex:0.90065	valid-auc:0.96229	valid-amex:0.79635
# [1200]	train-auc:0.98363	train-amex:0.90294	valid-auc:0.96230	valid-amex:0.79658
# [1400]	train-auc:0.98406	train-amex:0.90520	valid-auc:0.96232	valid-amex:0.79685
# [1600]	train-auc:0.98449	train-amex:0.90778	valid-auc:0.96234	valid-amex:0.79693
# [1800]	train-auc:0.98491	train-amex:0.91021	valid-auc:0.96235	valid-amex:0.79707
# [2000]	train-auc:0.98531	train-amex:0.91260	valid-auc:0.96237	valid-amex:0.79721
# [2200]	train-auc:0.98570	train-amex:0.91477	valid-auc:0.96238	valid-amex:0.79722
# [2400]	train-auc:0.98610	train-amex:0.91723	valid-auc:0.96239	valid-amex:0.79752
# [2600]	train-auc:0.98648	train-amex:0.91948	valid-auc:0.96239	valid-amex:0.79763
# [2800]	train-auc:0.98685	train-amex:0.92154	valid-auc:0.96240	valid-amex:0.79766
# [3000]	train-auc:0.98719	train-amex:0.92365	valid-auc:0.96240	valid-amex:0.79769
# [3200]	train-auc:0.98754	train-amex:0.92555	valid-auc:0.96241	valid-amex:0.79759
# [3400]	train-auc:0.98790	train-amex:0.92763	valid-auc:0.96241	valid-amex:0.79738
# [3600]	train-auc:0.98825	train-amex:0.92970	valid-auc:0.96242	valid-amex:0.79762
# [3800]	train-auc:0.98859	train-amex:0.93177	valid-auc:0.96242	valid-amex:0.79769
# [4000]	train-auc:0.98894	train-amex:0.93378	valid-auc:0.96243	valid-amex:0.79761
# [4200]	train-auc:0.98925	train-amex:0.93542	valid-auc:0.96243	valid-amex:0.79757
# [4400]	train-auc:0.98956	train-amex:0.93721	valid-auc:0.96243	valid-amex:0.79773
# [4600]	train-auc:0.98987	train-amex:0.93897	valid-auc:0.96242	valid-amex:0.79771
# [4800]	train-auc:0.99016	train-amex:0.94055	valid-auc:0.96243	valid-amex:0.79767
# [5000]	train-auc:0.99046	train-amex:0.94224	valid-auc:0.96244	valid-amex:0.79795
# [5199]	train-auc:0.99076	train-amex:0.94398	valid-auc:0.96244	valid-amex:0.79808
# Kaggle Metric = 0.797873445739456
#
# #########################
# ### Fold 5
# ### Train size 367131 Valid size 91782
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.95182	train-amex:0.75557	valid-auc:0.95126	valid-amex:0.75623
# [5]	train-auc:0.96337	train-amex:0.79876	valid-auc:0.95959	valid-amex:0.78458
# [9]	train-auc:0.96731	train-amex:0.81705	valid-auc:0.96109	valid-amex:0.78993
# [0]	train-auc:0.96695	train-amex:0.81532	valid-auc:0.96094	valid-amex:0.78898
# [25]	train-auc:0.96748	train-amex:0.81777	valid-auc:0.96103	valid-amex:0.79024
# [49]	train-auc:0.97025	train-amex:0.83148	valid-auc:0.96183	valid-amex:0.79390
# [0]	train-auc:0.97022	train-amex:0.83139	valid-auc:0.96183	valid-amex:0.79368
# [200]	train-auc:0.97045	train-amex:0.83265	valid-auc:0.96177	valid-amex:0.79394
# [399]	train-auc:0.97261	train-amex:0.84375	valid-auc:0.96225	valid-amex:0.79572
# [0]	train-auc:0.97258	train-amex:0.84363	valid-auc:0.96224	valid-amex:0.79570
# [200]	train-auc:0.97269	train-amex:0.84416	valid-auc:0.96219	valid-amex:0.79592
# [399]	train-auc:0.97434	train-amex:0.85229	valid-auc:0.96250	valid-amex:0.79692
# [0]	train-auc:0.97434	train-amex:0.85226	valid-auc:0.96249	valid-amex:0.79698
# [200]	train-auc:0.97505	train-amex:0.85650	valid-auc:0.96258	valid-amex:0.79748
# [400]	train-auc:0.97626	train-amex:0.86268	valid-auc:0.96273	valid-amex:0.79787
# [600]	train-auc:0.97736	train-amex:0.86862	valid-auc:0.96285	valid-amex:0.79826
# [800]	train-auc:0.97850	train-amex:0.87488	valid-auc:0.96296	valid-amex:0.79843
# [1000]	train-auc:0.97953	train-amex:0.88036	valid-auc:0.96304	valid-amex:0.79899
# [1199]	train-auc:0.98056	train-amex:0.88621	valid-auc:0.96311	valid-amex:0.79863
# [0]	train-auc:0.98056	train-amex:0.88629	valid-auc:0.96311	valid-amex:0.79867
# [200]	train-auc:0.98109	train-amex:0.88922	valid-auc:0.96314	valid-amex:0.79880
# [400]	train-auc:0.98157	train-amex:0.89172	valid-auc:0.96316	valid-amex:0.79913
# [600]	train-auc:0.98204	train-amex:0.89426	valid-auc:0.96318	valid-amex:0.79898
# [800]	train-auc:0.98252	train-amex:0.89688	valid-auc:0.96320	valid-amex:0.79888
# [1000]	train-auc:0.98298	train-amex:0.89935	valid-auc:0.96321	valid-amex:0.79914
# [1200]	train-auc:0.98343	train-amex:0.90198	valid-auc:0.96322	valid-amex:0.79897
# [1400]	train-auc:0.98387	train-amex:0.90438	valid-auc:0.96323	valid-amex:0.79959
# [1600]	train-auc:0.98430	train-amex:0.90668	valid-auc:0.96325	valid-amex:0.79975
# [1800]	train-auc:0.98470	train-amex:0.90885	valid-auc:0.96327	valid-amex:0.80009
# [2000]	train-auc:0.98510	train-amex:0.91095	valid-auc:0.96328	valid-amex:0.79995
# [2200]	train-auc:0.98551	train-amex:0.91330	valid-auc:0.96329	valid-amex:0.80011
# [2400]	train-auc:0.98589	train-amex:0.91556	valid-auc:0.96330	valid-amex:0.79980
# [2600]	train-auc:0.98626	train-amex:0.91767	valid-auc:0.96331	valid-amex:0.79987
# [2800]	train-auc:0.98662	train-amex:0.91964	valid-auc:0.96332	valid-amex:0.79944
# [3000]	train-auc:0.98699	train-amex:0.92183	valid-auc:0.96333	valid-amex:0.79975
# [3200]	train-auc:0.98737	train-amex:0.92401	valid-auc:0.96333	valid-amex:0.79992
# [3400]	train-auc:0.98772	train-amex:0.92608	valid-auc:0.96334	valid-amex:0.80015
# [3600]	train-auc:0.98807	train-amex:0.92814	valid-auc:0.96334	valid-amex:0.80016
# [3800]	train-auc:0.98843	train-amex:0.93021	valid-auc:0.96335	valid-amex:0.79987
# [3953]	train-auc:0.98868	train-amex:0.93176	valid-auc:0.96335	valid-amex:0.79978
# Kaggle Metric = 0.7995743366997212
#
# #########################
# OVERALL CV Kaggle Metric = 0.7974332837860327

# %%
# CLEAN RAM
del train
_ = gc.collect()

# %%
oof_xgb = pd.read_parquet('../input/amex-data-integer-dtypes-parquet-format/train.parquet', columns=['customer_ID']).drop_duplicates()
oof_xgb['customer_ID_hash'] = oof_xgb['customer_ID'].apply(lambda x: int(x[-16:],16) ).astype('int64')
oof_xgb = oof_xgb.set_index('customer_ID_hash')
oof_xgb = oof_xgb.merge(oof, left_index=True, right_index=True)
oof_xgb = oof_xgb.sort_index().reset_index(drop=True)
oof_xgb.to_csv(f'oof_xgb_v{VER}.csv',index=False)
oof_xgb.head()
# Out:
#                                          customer_ID  target  oof_pred
# 0  20eac26171c3d251c55fc78204e59fab1c15fc2bc96d0c...       1  1.028872
# 1  aea50fdf9b974ccec95fa177c3225a0f913483b457de6e...       0 -8.107467
# 2  32cd2d41aef737b69089882754395925c96eaee1f4a859...       0 -6.588468
# 3  8daa6d5dc2655a8a437531e6b8b96829113cdfe9bf6cae...       0 -3.595696
# 4  0ceba351a3851202542feb49d7385bcef32f6037fc57c7...       1  2.096829

# %%
oof_xgb
# Out:
#                                               customer_ID  target  oof_pred
# 0       20eac26171c3d251c55fc78204e59fab1c15fc2bc96d0c...       1  1.028872
# 1       aea50fdf9b974ccec95fa177c3225a0f913483b457de6e...       0 -8.107467
# 2       32cd2d41aef737b69089882754395925c96eaee1f4a859...       0 -6.588468
# 3       8daa6d5dc2655a8a437531e6b8b96829113cdfe9bf6cae...       0 -3.595696
# 4       0ceba351a3851202542feb49d7385bcef32f6037fc57c7...       1  2.096829
# ...                                                   ...     ...       ...
# 458908  295e48fc8327a967b857b36f767014bf3a13040d33edea...       0  0.403101
# 458909  c50efe7fde092c75efc7a6cd84689de399d7ae4f01aaed...       1  4.076441
# 458910  cabc752e0a8f813e720383aef769ffb48a1528d20dcb10...       1  2.209568
# 458911  4051ddc52bd37987009270ec48e55805021ccfd6e78f8e...       0 -4.863576
# 458912  af53daf78405275dfe14a776f61add190570294cc3051b...       1  2.311527
#
# [458913 rows x 3 columns]
