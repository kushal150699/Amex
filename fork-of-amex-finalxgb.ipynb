# %%
import pandas as pd
import numpy as np
import cupy,cudf 
import gc

# %%
SEED = 42
FOLDS = 5

# %%
TRAIN_PATH = '../input/amexfeatureengineering/770_FE_train.feather'
train = pd.read_feather(TRAIN_PATH)

# %%
train.shape
# Out:
# (458913, 772)

# %%
train.sample(5)
# Out:
#                 customer_ID  B_30_nunique  B_38_last  B_38_nunique  \
# 239875   418336341001300877             1          2             1
# 400335  6868324700994531223             1          3             1
# 428880  8014137752067627019             1          1             1
# 342441  4546763288999499503             1          2             1
# 435076  8258162537431698827             1          3             3
#
#         D_114_last  D_117_last  D_120_last  D_120_nunique  D_66_last  \
# 239875           2           5           1              1          0
# 400335           2           1           1              1          0
# 428880           1           5           2              2          0
# 342441           2           5           1              1          0
# 435076           1           1           1              1          0
#
#         D_66_nunique  ...  D_53_last_mean_diff  B_28_last_mean_diff  \
# 239875             1  ...             0.000000            -0.025208
# 400335             1  ...             0.000000            -0.107605
# 428880             1  ...            -0.003323             0.012474
# 342441             1  ...             0.000000            -0.036438
# 435076             1  ...             0.000000             0.033661
#
#         S_22_last_mean_diff  B_3_last_mean_diff  D_56_last_mean_diff  \
# 239875             0.014008           -0.000659             0.011551
# 400335             0.005424           -0.108459             0.000000
# 428880             0.443604           -0.002375             0.000000
# 342441             0.001087            0.002991             0.000000
# 435076             0.034637            0.021561             0.000000
#
#         D_130_last_mean_diff  S_7_last_mean_diff  total_data_count  \
# 239875                   0.0           -0.244141            2280.0
# 400335                   0.0           -0.013939            2266.0
# 428880                   0.0            0.027573            1704.0
# 342441                   0.0           -0.013756            2261.0
# 435076                   0.0            0.067200            2236.0
#
#         total_data_last  target
# 239875            175.0       0
# 400335            174.0       0
# 428880            176.0       1
# 342441            173.0       0
# 435076            174.0       1
#
# [5 rows x 772 columns]

# %%
FEATURES = [col for col in train.columns if col not in ['customer_ID','target']]
print(f"There are {len(FEATURES)} features!")
# Out:
# There are 770 features!

# %%
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb

xgb_params = {
            'objective': 'binary:logitraw', 
            'tree_method': 'gpu_hist',
            'predictor':'gpu_predictor',
            'max_depth': 7,    
            'subsample':0.9,   
            'colsample_bytree': 0.25,  
            'gamma':1.5,        
            'min_child_weight':8, 
            'lambda': 10,   
            'random_state':42,
            'eval_metric':'auc',
            'learning_rate':0.015,
            'num_parallel_tree':1,
    }

# %%
class IterLoadForDMatrix(xgb.core.DataIter):
    def __init__(self, df=None, features=None, target=None, batch_size=256*1024):
        self.features = features
        self.target = target
        self.df = df
        self.it = 0 # set iterator to 0
        self.batch_size = batch_size
        self.batches = int( np.ceil( len(df) / self.batch_size ) )
        super().__init__()

    def reset(self):
        '''Reset the iterator'''
        self.it = 0

    def next(self, input_data):
        '''Yield next batch of data.'''
        if self.it == self.batches:
            return 0 # Return 0 when there's no more batch.
        
        a = self.it * self.batch_size
        b = min( (self.it + 1) * self.batch_size, len(self.df) )
        dt = cudf.DataFrame(self.df.iloc[a:b])
        input_data(data=dt[self.features], label=dt[self.target]) #, weight=dt['weight'])
        self.it += 1
        return 1

# %%
def amex_metric_mod(y_true, y_pred):

    labels     = np.transpose(np.array([y_true, y_pred]))
    labels     = labels[labels[:, 1].argsort()[::-1]]
    weights    = np.where(labels[:,0]==0, 20, 1)
    cut_vals   = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four   = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])

    gini = [0,0]
    for i in [1,0]:
        labels         = np.transpose(np.array([y_true, y_pred]))
        labels         = labels[labels[:, i].argsort()[::-1]]
        weight         = np.where(labels[:,0]==0, 20, 1)
        weight_random  = np.cumsum(weight / np.sum(weight))
        total_pos      = np.sum(labels[:, 0] *  weight)
        cum_pos_found  = np.cumsum(labels[:, 0] * weight)
        lorentz        = cum_pos_found / total_pos
        gini[i]        = np.sum((lorentz - weight_random) * weight)

    return 0.5 * (gini[1]/gini[0] + top_four)

importances = []

# %%
oof = np.zeros((len(train)))
#train = train.to_pandas() # free GPU memory
TRAIN_SUBSAMPLE = 1.0
gc.collect() 

for SEED in [41,42,43]:
    oof_ = np.zeros((len(train)))
    skf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=SEED)
    for fold,(train_idx, valid_idx) in enumerate(skf.split(
            train, train.target )):
    
    # TRAIN WITH SUBSAMPLE OF TRAIN FOLD DATA
        if TRAIN_SUBSAMPLE<1.0:
                np.random.seed(SEED)
                train_idx = np.random.choice(train_idx, 
                       int(len(train_idx)*TRAIN_SUBSAMPLE), replace=False)
                np.random.seed(None)
    
        print('#'*25)
        print('### SEED',SEED)
        print('### Fold',fold+1)
        print('### Train size',len(train_idx),'Valid size',len(valid_idx))
        print(f'### Training with {int(TRAIN_SUBSAMPLE*100)}% fold data...')
        print('#'*25)
    
        # TRAIN, VALID, TEST FOR FOLD K
        Xy_train = IterLoadForDMatrix(train.loc[train_idx], FEATURES, 'target')
        X_valid = train.loc[valid_idx, FEATURES]
        y_valid = train.loc[valid_idx, 'target']
    

        dtrain = xgb.DeviceQuantileDMatrix(Xy_train, max_bin=256)
        dvalid = xgb.DMatrix(data=X_valid, label=y_valid)
    
         # TRAIN MODEL FOLD K
        model = xgb.train(xgb_params, 
                dtrain=dtrain,          
                evals=[(dtrain,'train'),(dvalid,'valid')],
                num_boost_round=9999,
                early_stopping_rounds=100,
                verbose_eval=100) 
        model.save_model(f'XGB_seed{SEED}_fold{fold}.xgb')
            
        # INFER OOF FOLD K
        oof_preds = model.predict(dvalid)
        acc = amex_metric_mod(y_valid.values, oof_preds)
        print('Kaggle Metric =',acc,'\n')
    
        # SAVE OOF
        oof_[valid_idx] = oof_preds

        del dtrain, Xy_train
        del X_valid, y_valid, dvalid, model
        _ = gc.collect()
        
    oof += oof_ / 3
       
    
print('#'*25)

acc = amex_metric_mod(train.target, oof)
print('OVERALL CV Kaggle Metric =',acc)
# Out:
# #########################
# ### SEED 41
# ### Fold 1
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93947	valid-auc:0.93679
# [100]	train-auc:0.95700	valid-auc:0.95355
# [200]	train-auc:0.96016	valid-auc:0.95583
# [300]	train-auc:0.96250	valid-auc:0.95738
# [400]	train-auc:0.96433	valid-auc:0.95846
# [500]	train-auc:0.96600	valid-auc:0.95928
# [600]	train-auc:0.96737	valid-auc:0.95981
# [700]	train-auc:0.96856	valid-auc:0.96021
# [800]	train-auc:0.96964	valid-auc:0.96051
# [900]	train-auc:0.97059	valid-auc:0.96074
# [1000]	train-auc:0.97149	valid-auc:0.96093
# [1100]	train-auc:0.97235	valid-auc:0.96108
# [1200]	train-auc:0.97315	valid-auc:0.96122
# [1300]	train-auc:0.97388	valid-auc:0.96133
# [1400]	train-auc:0.97463	valid-auc:0.96143
# [1500]	train-auc:0.97531	valid-auc:0.96153
# [1600]	train-auc:0.97600	valid-auc:0.96162
# [1700]	train-auc:0.97661	valid-auc:0.96167
# [1800]	train-auc:0.97723	valid-auc:0.96173
# [1900]	train-auc:0.97783	valid-auc:0.96177
# [2000]	train-auc:0.97843	valid-auc:0.96182
# [2100]	train-auc:0.97901	valid-auc:0.96186
# [2200]	train-auc:0.97955	valid-auc:0.96190
# [2300]	train-auc:0.98005	valid-auc:0.96193
# [2400]	train-auc:0.98057	valid-auc:0.96196
# [2500]	train-auc:0.98108	valid-auc:0.96199
# [2600]	train-auc:0.98157	valid-auc:0.96202
# [2700]	train-auc:0.98205	valid-auc:0.96203
# [2800]	train-auc:0.98252	valid-auc:0.96206
# [2900]	train-auc:0.98295	valid-auc:0.96207
# [3000]	train-auc:0.98341	valid-auc:0.96209
# [3100]	train-auc:0.98385	valid-auc:0.96210
# [3200]	train-auc:0.98429	valid-auc:0.96212
# [3300]	train-auc:0.98473	valid-auc:0.96212
# [3400]	train-auc:0.98515	valid-auc:0.96214
# [3500]	train-auc:0.98559	valid-auc:0.96215
# [3600]	train-auc:0.98598	valid-auc:0.96216
# [3700]	train-auc:0.98637	valid-auc:0.96217
# [3800]	train-auc:0.98676	valid-auc:0.96217
# [3900]	train-auc:0.98711	valid-auc:0.96218
# [4000]	train-auc:0.98746	valid-auc:0.96218
# [4069]	train-auc:0.98769	valid-auc:0.96218
# Kaggle Metric = 0.7938684282634663
#
# #########################
# ### SEED 41
# ### Fold 2
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93928	valid-auc:0.93629
# [100]	train-auc:0.95699	valid-auc:0.95328
# [200]	train-auc:0.96015	valid-auc:0.95560
# [300]	train-auc:0.96251	valid-auc:0.95721
# [400]	train-auc:0.96435	valid-auc:0.95831
# [500]	train-auc:0.96602	valid-auc:0.95914
# [600]	train-auc:0.96741	valid-auc:0.95970
# [700]	train-auc:0.96862	valid-auc:0.96012
# [800]	train-auc:0.96971	valid-auc:0.96044
# [900]	train-auc:0.97072	valid-auc:0.96067
# [1000]	train-auc:0.97167	valid-auc:0.96086
# [1100]	train-auc:0.97249	valid-auc:0.96101
# [1200]	train-auc:0.97328	valid-auc:0.96116
# [1300]	train-auc:0.97407	valid-auc:0.96126
# [1400]	train-auc:0.97478	valid-auc:0.96135
# [1500]	train-auc:0.97550	valid-auc:0.96143
# [1600]	train-auc:0.97615	valid-auc:0.96150
# [1700]	train-auc:0.97681	valid-auc:0.96156
# [1800]	train-auc:0.97740	valid-auc:0.96161
# [1900]	train-auc:0.97799	valid-auc:0.96167
# [2000]	train-auc:0.97856	valid-auc:0.96170
# [2100]	train-auc:0.97912	valid-auc:0.96175
# [2200]	train-auc:0.97966	valid-auc:0.96179
# [2300]	train-auc:0.98021	valid-auc:0.96181
# [2400]	train-auc:0.98072	valid-auc:0.96184
# [2500]	train-auc:0.98122	valid-auc:0.96186
# [2600]	train-auc:0.98172	valid-auc:0.96188
# [2700]	train-auc:0.98222	valid-auc:0.96192
# [2800]	train-auc:0.98272	valid-auc:0.96194
# [2900]	train-auc:0.98315	valid-auc:0.96196
# [3000]	train-auc:0.98359	valid-auc:0.96197
# [3100]	train-auc:0.98404	valid-auc:0.96197
# [3200]	train-auc:0.98444	valid-auc:0.96199
# [3300]	train-auc:0.98485	valid-auc:0.96201
# [3400]	train-auc:0.98527	valid-auc:0.96202
# [3500]	train-auc:0.98568	valid-auc:0.96202
# [3600]	train-auc:0.98609	valid-auc:0.96203
# [3700]	train-auc:0.98646	valid-auc:0.96204
# [3800]	train-auc:0.98684	valid-auc:0.96205
# [3900]	train-auc:0.98720	valid-auc:0.96206
# [4000]	train-auc:0.98755	valid-auc:0.96206
# [4100]	train-auc:0.98792	valid-auc:0.96207
# [4200]	train-auc:0.98828	valid-auc:0.96207
# [4290]	train-auc:0.98859	valid-auc:0.96207
# Kaggle Metric = 0.793196630375248
#
# #########################
# ### SEED 41
# ### Fold 3
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93918	valid-auc:0.93814
# [100]	train-auc:0.95682	valid-auc:0.95436
# [200]	train-auc:0.95998	valid-auc:0.95669
# [300]	train-auc:0.96232	valid-auc:0.95826
# [400]	train-auc:0.96416	valid-auc:0.95934
# [500]	train-auc:0.96586	valid-auc:0.96014
# [600]	train-auc:0.96720	valid-auc:0.96067
# [700]	train-auc:0.96843	valid-auc:0.96106
# [800]	train-auc:0.96953	valid-auc:0.96135
# [900]	train-auc:0.97052	valid-auc:0.96158
# [1000]	train-auc:0.97146	valid-auc:0.96178
# [1100]	train-auc:0.97236	valid-auc:0.96194
# [1200]	train-auc:0.97315	valid-auc:0.96207
# [1300]	train-auc:0.97391	valid-auc:0.96218
# [1400]	train-auc:0.97462	valid-auc:0.96226
# [1500]	train-auc:0.97530	valid-auc:0.96234
# [1600]	train-auc:0.97595	valid-auc:0.96240
# [1700]	train-auc:0.97659	valid-auc:0.96246
# [1800]	train-auc:0.97725	valid-auc:0.96251
# [1900]	train-auc:0.97788	valid-auc:0.96255
# [2000]	train-auc:0.97843	valid-auc:0.96260
# [2100]	train-auc:0.97898	valid-auc:0.96264
# [2200]	train-auc:0.97951	valid-auc:0.96268
# [2300]	train-auc:0.98002	valid-auc:0.96270
# [2400]	train-auc:0.98057	valid-auc:0.96274
# [2500]	train-auc:0.98108	valid-auc:0.96277
# [2600]	train-auc:0.98162	valid-auc:0.96278
# [2700]	train-auc:0.98208	valid-auc:0.96281
# [2800]	train-auc:0.98254	valid-auc:0.96282
# [2900]	train-auc:0.98302	valid-auc:0.96284
# [3000]	train-auc:0.98349	valid-auc:0.96285
# [3100]	train-auc:0.98392	valid-auc:0.96286
# [3200]	train-auc:0.98436	valid-auc:0.96287
# [3300]	train-auc:0.98476	valid-auc:0.96288
# [3400]	train-auc:0.98519	valid-auc:0.96289
# [3500]	train-auc:0.98564	valid-auc:0.96290
# [3600]	train-auc:0.98603	valid-auc:0.96292
# [3700]	train-auc:0.98642	valid-auc:0.96293
# [3800]	train-auc:0.98681	valid-auc:0.96294
# [3900]	train-auc:0.98719	valid-auc:0.96295
# [4000]	train-auc:0.98756	valid-auc:0.96296
# [4100]	train-auc:0.98790	valid-auc:0.96295
# [4109]	train-auc:0.98793	valid-auc:0.96295
# Kaggle Metric = 0.8001782415931982
#
# #########################
# ### SEED 41
# ### Fold 4
# ### Train size 367131 Valid size 91782
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93937	valid-auc:0.93899
# [100]	train-auc:0.95663	valid-auc:0.95471
# [200]	train-auc:0.95991	valid-auc:0.95712
# [300]	train-auc:0.96226	valid-auc:0.95868
# [400]	train-auc:0.96413	valid-auc:0.95971
# [500]	train-auc:0.96580	valid-auc:0.96046
# [600]	train-auc:0.96721	valid-auc:0.96099
# [700]	train-auc:0.96842	valid-auc:0.96135
# [800]	train-auc:0.96950	valid-auc:0.96161
# [900]	train-auc:0.97052	valid-auc:0.96184
# [1000]	train-auc:0.97143	valid-auc:0.96201
# [1100]	train-auc:0.97231	valid-auc:0.96217
# [1200]	train-auc:0.97313	valid-auc:0.96228
# [1300]	train-auc:0.97390	valid-auc:0.96237
# [1400]	train-auc:0.97459	valid-auc:0.96244
# [1500]	train-auc:0.97529	valid-auc:0.96251
# [1600]	train-auc:0.97594	valid-auc:0.96258
# [1700]	train-auc:0.97661	valid-auc:0.96264
# [1800]	train-auc:0.97719	valid-auc:0.96268
# [1900]	train-auc:0.97782	valid-auc:0.96273
# [2000]	train-auc:0.97841	valid-auc:0.96277
# [2100]	train-auc:0.97896	valid-auc:0.96281
# [2200]	train-auc:0.97950	valid-auc:0.96284
# [2300]	train-auc:0.98002	valid-auc:0.96286
# [2400]	train-auc:0.98055	valid-auc:0.96288
# [2500]	train-auc:0.98101	valid-auc:0.96292
# [2600]	train-auc:0.98152	valid-auc:0.96294
# [2700]	train-auc:0.98204	valid-auc:0.96296
# [2800]	train-auc:0.98253	valid-auc:0.96299
# [2900]	train-auc:0.98297	valid-auc:0.96301
# [3000]	train-auc:0.98342	valid-auc:0.96303
# [3100]	train-auc:0.98382	valid-auc:0.96305
# [3200]	train-auc:0.98428	valid-auc:0.96307
# [3300]	train-auc:0.98467	valid-auc:0.96308
# [3400]	train-auc:0.98508	valid-auc:0.96310
# [3500]	train-auc:0.98548	valid-auc:0.96310
# [3600]	train-auc:0.98586	valid-auc:0.96311
# [3700]	train-auc:0.98625	valid-auc:0.96311
# [3800]	train-auc:0.98664	valid-auc:0.96311
# [3838]	train-auc:0.98679	valid-auc:0.96311
# Kaggle Metric = 0.7977638692697894
#
# #########################
# ### SEED 41
# ### Fold 5
# ### Train size 367131 Valid size 91782
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93897	valid-auc:0.93743
# [100]	train-auc:0.95673	valid-auc:0.95471
# [200]	train-auc:0.95989	valid-auc:0.95696
# [300]	train-auc:0.96227	valid-auc:0.95848
# [400]	train-auc:0.96413	valid-auc:0.95951
# [500]	train-auc:0.96583	valid-auc:0.96025
# [600]	train-auc:0.96724	valid-auc:0.96073
# [700]	train-auc:0.96841	valid-auc:0.96107
# [800]	train-auc:0.96949	valid-auc:0.96134
# [900]	train-auc:0.97047	valid-auc:0.96155
# [1000]	train-auc:0.97142	valid-auc:0.96171
# [1100]	train-auc:0.97227	valid-auc:0.96185
# [1200]	train-auc:0.97308	valid-auc:0.96196
# [1300]	train-auc:0.97382	valid-auc:0.96205
# [1400]	train-auc:0.97453	valid-auc:0.96213
# [1500]	train-auc:0.97525	valid-auc:0.96220
# [1600]	train-auc:0.97589	valid-auc:0.96225
# [1700]	train-auc:0.97654	valid-auc:0.96230
# [1800]	train-auc:0.97714	valid-auc:0.96235
# [1900]	train-auc:0.97772	valid-auc:0.96239
# [2000]	train-auc:0.97829	valid-auc:0.96244
# [2100]	train-auc:0.97884	valid-auc:0.96247
# [2200]	train-auc:0.97940	valid-auc:0.96251
# [2300]	train-auc:0.97994	valid-auc:0.96253
# [2400]	train-auc:0.98046	valid-auc:0.96256
# [2500]	train-auc:0.98097	valid-auc:0.96259
# [2600]	train-auc:0.98144	valid-auc:0.96260
# [2700]	train-auc:0.98194	valid-auc:0.96263
# [2800]	train-auc:0.98242	valid-auc:0.96264
# [2900]	train-auc:0.98290	valid-auc:0.96266
# [3000]	train-auc:0.98336	valid-auc:0.96268
# [3100]	train-auc:0.98381	valid-auc:0.96269
# [3200]	train-auc:0.98423	valid-auc:0.96268
# [3300]	train-auc:0.98464	valid-auc:0.96269
# [3400]	train-auc:0.98504	valid-auc:0.96272
# [3500]	train-auc:0.98543	valid-auc:0.96272
# [3600]	train-auc:0.98582	valid-auc:0.96273
# [3700]	train-auc:0.98623	valid-auc:0.96274
# [3800]	train-auc:0.98659	valid-auc:0.96275
# [3900]	train-auc:0.98697	valid-auc:0.96277
# [4000]	train-auc:0.98732	valid-auc:0.96277
# [4100]	train-auc:0.98769	valid-auc:0.96278
# [4200]	train-auc:0.98804	valid-auc:0.96278
# [4300]	train-auc:0.98839	valid-auc:0.96279
# [4377]	train-auc:0.98863	valid-auc:0.96278
# Kaggle Metric = 0.7952831244706813
#
# #########################
# ### SEED 42
# ### Fold 1
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93965	valid-auc:0.93746
# [100]	train-auc:0.95687	valid-auc:0.95404
# [200]	train-auc:0.96004	valid-auc:0.95642
# [300]	train-auc:0.96235	valid-auc:0.95800
# [400]	train-auc:0.96420	valid-auc:0.95907
# [500]	train-auc:0.96589	valid-auc:0.95988
# [600]	train-auc:0.96724	valid-auc:0.96040
# [700]	train-auc:0.96840	valid-auc:0.96078
# [800]	train-auc:0.96945	valid-auc:0.96107
# [900]	train-auc:0.97041	valid-auc:0.96130
# [1000]	train-auc:0.97130	valid-auc:0.96149
# [1100]	train-auc:0.97213	valid-auc:0.96166
# [1200]	train-auc:0.97291	valid-auc:0.96179
# [1300]	train-auc:0.97371	valid-auc:0.96191
# [1400]	train-auc:0.97442	valid-auc:0.96200
# [1500]	train-auc:0.97510	valid-auc:0.96206
# [1600]	train-auc:0.97575	valid-auc:0.96214
# [1700]	train-auc:0.97636	valid-auc:0.96219
# [1800]	train-auc:0.97697	valid-auc:0.96224
# [1900]	train-auc:0.97753	valid-auc:0.96229
# [2000]	train-auc:0.97810	valid-auc:0.96233
# [2100]	train-auc:0.97863	valid-auc:0.96237
# [2200]	train-auc:0.97919	valid-auc:0.96241
# [2300]	train-auc:0.97967	valid-auc:0.96243
# [2400]	train-auc:0.98020	valid-auc:0.96246
# [2500]	train-auc:0.98071	valid-auc:0.96248
# [2600]	train-auc:0.98118	valid-auc:0.96250
# [2700]	train-auc:0.98164	valid-auc:0.96252
# [2800]	train-auc:0.98209	valid-auc:0.96254
# [2900]	train-auc:0.98258	valid-auc:0.96255
# [3000]	train-auc:0.98306	valid-auc:0.96257
# [3100]	train-auc:0.98351	valid-auc:0.96258
# [3200]	train-auc:0.98395	valid-auc:0.96259
# [3300]	train-auc:0.98438	valid-auc:0.96259
# [3400]	train-auc:0.98475	valid-auc:0.96260
# [3500]	train-auc:0.98516	valid-auc:0.96261
# [3600]	train-auc:0.98555	valid-auc:0.96263
# [3700]	train-auc:0.98594	valid-auc:0.96263
# [3800]	train-auc:0.98633	valid-auc:0.96265
# [3900]	train-auc:0.98671	valid-auc:0.96266
# [4000]	train-auc:0.98708	valid-auc:0.96267
# [4100]	train-auc:0.98747	valid-auc:0.96268
# [4200]	train-auc:0.98779	valid-auc:0.96268
# [4300]	train-auc:0.98817	valid-auc:0.96269
# [4400]	train-auc:0.98854	valid-auc:0.96270
# [4500]	train-auc:0.98889	valid-auc:0.96271
# [4600]	train-auc:0.98925	valid-auc:0.96271
# [4700]	train-auc:0.98957	valid-auc:0.96272
# [4800]	train-auc:0.98990	valid-auc:0.96272
# [4863]	train-auc:0.99010	valid-auc:0.96272
# Kaggle Metric = 0.7955240575552535
#
# #########################
# ### SEED 42
# ### Fold 2
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93905	valid-auc:0.93742
# [100]	train-auc:0.95679	valid-auc:0.95363
# [200]	train-auc:0.96004	valid-auc:0.95607
# [300]	train-auc:0.96240	valid-auc:0.95766
# [400]	train-auc:0.96426	valid-auc:0.95878
# [500]	train-auc:0.96595	valid-auc:0.95959
# [600]	train-auc:0.96738	valid-auc:0.96016
# [700]	train-auc:0.96861	valid-auc:0.96055
# [800]	train-auc:0.96971	valid-auc:0.96085
# [900]	train-auc:0.97069	valid-auc:0.96107
# [1000]	train-auc:0.97158	valid-auc:0.96126
# [1100]	train-auc:0.97248	valid-auc:0.96141
# [1200]	train-auc:0.97333	valid-auc:0.96155
# [1300]	train-auc:0.97409	valid-auc:0.96166
# [1400]	train-auc:0.97487	valid-auc:0.96175
# [1500]	train-auc:0.97557	valid-auc:0.96182
# [1600]	train-auc:0.97623	valid-auc:0.96189
# [1700]	train-auc:0.97692	valid-auc:0.96197
# [1800]	train-auc:0.97751	valid-auc:0.96202
# [1900]	train-auc:0.97812	valid-auc:0.96207
# [2000]	train-auc:0.97873	valid-auc:0.96210
# [2100]	train-auc:0.97934	valid-auc:0.96215
# [2200]	train-auc:0.97990	valid-auc:0.96219
# [2300]	train-auc:0.98041	valid-auc:0.96222
# [2400]	train-auc:0.98093	valid-auc:0.96225
# [2500]	train-auc:0.98142	valid-auc:0.96228
# [2600]	train-auc:0.98190	valid-auc:0.96231
# [2700]	train-auc:0.98238	valid-auc:0.96233
# [2800]	train-auc:0.98285	valid-auc:0.96235
# [2900]	train-auc:0.98333	valid-auc:0.96236
# [3000]	train-auc:0.98378	valid-auc:0.96238
# [3100]	train-auc:0.98423	valid-auc:0.96238
# [3200]	train-auc:0.98466	valid-auc:0.96239
# [3300]	train-auc:0.98508	valid-auc:0.96240
# [3400]	train-auc:0.98549	valid-auc:0.96241
# [3500]	train-auc:0.98595	valid-auc:0.96243
# [3600]	train-auc:0.98634	valid-auc:0.96244
# [3700]	train-auc:0.98675	valid-auc:0.96244
# [3800]	train-auc:0.98710	valid-auc:0.96245
# [3900]	train-auc:0.98748	valid-auc:0.96245
# [3966]	train-auc:0.98770	valid-auc:0.96245
# Kaggle Metric = 0.7968606937305296
#
# #########################
# ### SEED 42
# ### Fold 3
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93904	valid-auc:0.93699
# [100]	train-auc:0.95683	valid-auc:0.95399
# [200]	train-auc:0.96001	valid-auc:0.95637
# [300]	train-auc:0.96237	valid-auc:0.95793
# [400]	train-auc:0.96419	valid-auc:0.95906
# [500]	train-auc:0.96587	valid-auc:0.95987
# [600]	train-auc:0.96727	valid-auc:0.96042
# [700]	train-auc:0.96846	valid-auc:0.96079
# [800]	train-auc:0.96956	valid-auc:0.96107
# [900]	train-auc:0.97053	valid-auc:0.96129
# [1000]	train-auc:0.97145	valid-auc:0.96148
# [1100]	train-auc:0.97233	valid-auc:0.96162
# [1200]	train-auc:0.97313	valid-auc:0.96174
# [1300]	train-auc:0.97387	valid-auc:0.96184
# [1400]	train-auc:0.97456	valid-auc:0.96193
# [1500]	train-auc:0.97525	valid-auc:0.96200
# [1600]	train-auc:0.97592	valid-auc:0.96206
# [1700]	train-auc:0.97650	valid-auc:0.96211
# [1800]	train-auc:0.97714	valid-auc:0.96217
# [1900]	train-auc:0.97775	valid-auc:0.96221
# [2000]	train-auc:0.97832	valid-auc:0.96225
# [2100]	train-auc:0.97883	valid-auc:0.96229
# [2200]	train-auc:0.97937	valid-auc:0.96230
# [2300]	train-auc:0.97993	valid-auc:0.96234
# [2400]	train-auc:0.98044	valid-auc:0.96236
# [2500]	train-auc:0.98094	valid-auc:0.96238
# [2600]	train-auc:0.98144	valid-auc:0.96240
# [2700]	train-auc:0.98197	valid-auc:0.96242
# [2800]	train-auc:0.98245	valid-auc:0.96243
# [2900]	train-auc:0.98289	valid-auc:0.96244
# [3000]	train-auc:0.98331	valid-auc:0.96246
# [3100]	train-auc:0.98379	valid-auc:0.96246
# [3122]	train-auc:0.98390	valid-auc:0.96246
# Kaggle Metric = 0.7981939058444958
#
# #########################
# ### SEED 42
# ### Fold 4
# ### Train size 367131 Valid size 91782
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93921	valid-auc:0.93717
# [100]	train-auc:0.95695	valid-auc:0.95386
# [200]	train-auc:0.96013	valid-auc:0.95610
# [300]	train-auc:0.96250	valid-auc:0.95759
# [400]	train-auc:0.96434	valid-auc:0.95857
# [500]	train-auc:0.96603	valid-auc:0.95934
# [600]	train-auc:0.96738	valid-auc:0.95987
# [700]	train-auc:0.96860	valid-auc:0.96025
# [800]	train-auc:0.96965	valid-auc:0.96053
# [900]	train-auc:0.97064	valid-auc:0.96076
# [1000]	train-auc:0.97157	valid-auc:0.96095
# [1100]	train-auc:0.97242	valid-auc:0.96111
# [1200]	train-auc:0.97325	valid-auc:0.96123
# [1300]	train-auc:0.97404	valid-auc:0.96135
# [1400]	train-auc:0.97476	valid-auc:0.96144
# [1500]	train-auc:0.97547	valid-auc:0.96152
# [1600]	train-auc:0.97614	valid-auc:0.96160
# [1700]	train-auc:0.97679	valid-auc:0.96167
# [1800]	train-auc:0.97743	valid-auc:0.96172
# [1900]	train-auc:0.97801	valid-auc:0.96176
# [2000]	train-auc:0.97857	valid-auc:0.96181
# [2100]	train-auc:0.97912	valid-auc:0.96185
# [2200]	train-auc:0.97964	valid-auc:0.96189
# [2300]	train-auc:0.98019	valid-auc:0.96192
# [2400]	train-auc:0.98073	valid-auc:0.96195
# [2500]	train-auc:0.98121	valid-auc:0.96198
# [2600]	train-auc:0.98174	valid-auc:0.96201
# [2700]	train-auc:0.98221	valid-auc:0.96203
# [2800]	train-auc:0.98268	valid-auc:0.96206
# [2900]	train-auc:0.98314	valid-auc:0.96207
# [3000]	train-auc:0.98359	valid-auc:0.96209
# [3100]	train-auc:0.98403	valid-auc:0.96211
# [3200]	train-auc:0.98444	valid-auc:0.96212
# [3300]	train-auc:0.98489	valid-auc:0.96213
# [3400]	train-auc:0.98531	valid-auc:0.96213
# [3500]	train-auc:0.98571	valid-auc:0.96213
# [3600]	train-auc:0.98611	valid-auc:0.96215
# [3700]	train-auc:0.98649	valid-auc:0.96215
# [3800]	train-auc:0.98687	valid-auc:0.96217
# [3900]	train-auc:0.98723	valid-auc:0.96217
# [4000]	train-auc:0.98759	valid-auc:0.96217
# [4100]	train-auc:0.98791	valid-auc:0.96218
# [4200]	train-auc:0.98827	valid-auc:0.96220
# [4300]	train-auc:0.98861	valid-auc:0.96220
# [4400]	train-auc:0.98895	valid-auc:0.96221
# [4500]	train-auc:0.98927	valid-auc:0.96222
# [4600]	train-auc:0.98959	valid-auc:0.96222
# [4700]	train-auc:0.98988	valid-auc:0.96222
# [4800]	train-auc:0.99018	valid-auc:0.96223
# [4900]	train-auc:0.99047	valid-auc:0.96225
# [5000]	train-auc:0.99077	valid-auc:0.96225
# [5100]	train-auc:0.99107	valid-auc:0.96225
# [5122]	train-auc:0.99112	valid-auc:0.96225
# Kaggle Metric = 0.7972793748336393
#
# #########################
# ### SEED 42
# ### Fold 5
# ### Train size 367131 Valid size 91782
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93850	valid-auc:0.93876
# [100]	train-auc:0.95666	valid-auc:0.95500
# [200]	train-auc:0.95988	valid-auc:0.95722
# [300]	train-auc:0.96225	valid-auc:0.95874
# [400]	train-auc:0.96411	valid-auc:0.95976
# [500]	train-auc:0.96580	valid-auc:0.96050
# [600]	train-auc:0.96724	valid-auc:0.96101
# [700]	train-auc:0.96844	valid-auc:0.96135
# [800]	train-auc:0.96955	valid-auc:0.96163
# [900]	train-auc:0.97051	valid-auc:0.96183
# [1000]	train-auc:0.97145	valid-auc:0.96201
# [1100]	train-auc:0.97229	valid-auc:0.96215
# [1200]	train-auc:0.97304	valid-auc:0.96225
# [1300]	train-auc:0.97381	valid-auc:0.96237
# [1400]	train-auc:0.97453	valid-auc:0.96245
# [1500]	train-auc:0.97520	valid-auc:0.96253
# [1600]	train-auc:0.97584	valid-auc:0.96259
# [1700]	train-auc:0.97646	valid-auc:0.96266
# [1800]	train-auc:0.97707	valid-auc:0.96272
# [1900]	train-auc:0.97770	valid-auc:0.96277
# [2000]	train-auc:0.97827	valid-auc:0.96281
# [2100]	train-auc:0.97887	valid-auc:0.96285
# [2200]	train-auc:0.97941	valid-auc:0.96289
# [2300]	train-auc:0.97994	valid-auc:0.96293
# [2400]	train-auc:0.98046	valid-auc:0.96295
# [2500]	train-auc:0.98094	valid-auc:0.96297
# [2600]	train-auc:0.98142	valid-auc:0.96299
# [2700]	train-auc:0.98189	valid-auc:0.96301
# [2800]	train-auc:0.98235	valid-auc:0.96304
# [2900]	train-auc:0.98283	valid-auc:0.96306
# [3000]	train-auc:0.98326	valid-auc:0.96308
# [3100]	train-auc:0.98370	valid-auc:0.96308
# [3200]	train-auc:0.98415	valid-auc:0.96309
# [3300]	train-auc:0.98457	valid-auc:0.96310
# [3400]	train-auc:0.98499	valid-auc:0.96311
# [3500]	train-auc:0.98543	valid-auc:0.96313
# [3600]	train-auc:0.98582	valid-auc:0.96314
# [3700]	train-auc:0.98622	valid-auc:0.96315
# [3800]	train-auc:0.98662	valid-auc:0.96317
# [3900]	train-auc:0.98700	valid-auc:0.96318
# [4000]	train-auc:0.98736	valid-auc:0.96318
# [4100]	train-auc:0.98773	valid-auc:0.96319
# [4152]	train-auc:0.98791	valid-auc:0.96319
# Kaggle Metric = 0.7994846513354652
#
# #########################
# ### SEED 43
# ### Fold 1
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93914	valid-auc:0.93621
# [100]	train-auc:0.95692	valid-auc:0.95377
# [200]	train-auc:0.96013	valid-auc:0.95607
# [300]	train-auc:0.96246	valid-auc:0.95755
# [400]	train-auc:0.96432	valid-auc:0.95861
# [500]	train-auc:0.96602	valid-auc:0.95941
# [600]	train-auc:0.96742	valid-auc:0.95994
# [700]	train-auc:0.96863	valid-auc:0.96032
# [800]	train-auc:0.96971	valid-auc:0.96061
# [900]	train-auc:0.97069	valid-auc:0.96082
# [1000]	train-auc:0.97164	valid-auc:0.96101
# [1100]	train-auc:0.97251	valid-auc:0.96116
# [1200]	train-auc:0.97328	valid-auc:0.96127
# [1300]	train-auc:0.97404	valid-auc:0.96138
# [1400]	train-auc:0.97472	valid-auc:0.96147
# [1500]	train-auc:0.97542	valid-auc:0.96155
# [1600]	train-auc:0.97610	valid-auc:0.96162
# [1700]	train-auc:0.97674	valid-auc:0.96168
# [1800]	train-auc:0.97733	valid-auc:0.96173
# [1900]	train-auc:0.97795	valid-auc:0.96179
# [2000]	train-auc:0.97849	valid-auc:0.96182
# [2100]	train-auc:0.97905	valid-auc:0.96185
# [2200]	train-auc:0.97958	valid-auc:0.96189
# [2300]	train-auc:0.98011	valid-auc:0.96192
# [2400]	train-auc:0.98064	valid-auc:0.96195
# [2500]	train-auc:0.98114	valid-auc:0.96198
# [2600]	train-auc:0.98160	valid-auc:0.96200
# [2700]	train-auc:0.98205	valid-auc:0.96202
# [2800]	train-auc:0.98252	valid-auc:0.96204
# [2900]	train-auc:0.98299	valid-auc:0.96206
# [3000]	train-auc:0.98343	valid-auc:0.96208
# [3100]	train-auc:0.98387	valid-auc:0.96209
# [3200]	train-auc:0.98428	valid-auc:0.96211
# [3300]	train-auc:0.98471	valid-auc:0.96213
# [3400]	train-auc:0.98514	valid-auc:0.96215
# [3500]	train-auc:0.98556	valid-auc:0.96215
# [3600]	train-auc:0.98596	valid-auc:0.96217
# [3700]	train-auc:0.98637	valid-auc:0.96217
# [3800]	train-auc:0.98676	valid-auc:0.96218
# [3900]	train-auc:0.98711	valid-auc:0.96220
# [3997]	train-auc:0.98749	valid-auc:0.96219
# Kaggle Metric = 0.7924563701501205
#
# #########################
# ### SEED 43
# ### Fold 2
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93881	valid-auc:0.93595
# [100]	train-auc:0.95704	valid-auc:0.95331
# [200]	train-auc:0.96017	valid-auc:0.95570
# [300]	train-auc:0.96251	valid-auc:0.95732
# [400]	train-auc:0.96434	valid-auc:0.95841
# [500]	train-auc:0.96599	valid-auc:0.95921
# [600]	train-auc:0.96735	valid-auc:0.95976
# [700]	train-auc:0.96852	valid-auc:0.96018
# [800]	train-auc:0.96960	valid-auc:0.96050
# [900]	train-auc:0.97056	valid-auc:0.96074
# [1000]	train-auc:0.97149	valid-auc:0.96094
# [1100]	train-auc:0.97237	valid-auc:0.96112
# [1200]	train-auc:0.97322	valid-auc:0.96126
# [1300]	train-auc:0.97398	valid-auc:0.96139
# [1400]	train-auc:0.97472	valid-auc:0.96151
# [1500]	train-auc:0.97544	valid-auc:0.96159
# [1600]	train-auc:0.97612	valid-auc:0.96168
# [1700]	train-auc:0.97678	valid-auc:0.96175
# [1800]	train-auc:0.97741	valid-auc:0.96182
# [1900]	train-auc:0.97800	valid-auc:0.96188
# [2000]	train-auc:0.97858	valid-auc:0.96192
# [2100]	train-auc:0.97914	valid-auc:0.96196
# [2200]	train-auc:0.97971	valid-auc:0.96201
# [2300]	train-auc:0.98023	valid-auc:0.96204
# [2400]	train-auc:0.98076	valid-auc:0.96209
# [2500]	train-auc:0.98124	valid-auc:0.96211
# [2600]	train-auc:0.98171	valid-auc:0.96214
# [2700]	train-auc:0.98221	valid-auc:0.96217
# [2800]	train-auc:0.98269	valid-auc:0.96218
# [2900]	train-auc:0.98315	valid-auc:0.96220
# [3000]	train-auc:0.98362	valid-auc:0.96223
# [3100]	train-auc:0.98406	valid-auc:0.96225
# [3200]	train-auc:0.98450	valid-auc:0.96227
# [3300]	train-auc:0.98496	valid-auc:0.96229
# [3400]	train-auc:0.98537	valid-auc:0.96231
# [3500]	train-auc:0.98576	valid-auc:0.96233
# [3600]	train-auc:0.98615	valid-auc:0.96234
# [3700]	train-auc:0.98654	valid-auc:0.96235
# [3800]	train-auc:0.98695	valid-auc:0.96236
# [3900]	train-auc:0.98733	valid-auc:0.96237
# [4000]	train-auc:0.98767	valid-auc:0.96238
# [4050]	train-auc:0.98786	valid-auc:0.96237
# Kaggle Metric = 0.7982101172075855
#
# #########################
# ### SEED 43
# ### Fold 3
# ### Train size 367130 Valid size 91783
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93885	valid-auc:0.93712
# [100]	train-auc:0.95683	valid-auc:0.95410
# [200]	train-auc:0.96001	valid-auc:0.95636
# [300]	train-auc:0.96237	valid-auc:0.95791
# [400]	train-auc:0.96425	valid-auc:0.95898
# [500]	train-auc:0.96592	valid-auc:0.95974
# [600]	train-auc:0.96730	valid-auc:0.96026
# [700]	train-auc:0.96851	valid-auc:0.96063
# [800]	train-auc:0.96958	valid-auc:0.96093
# [900]	train-auc:0.97054	valid-auc:0.96114
# [1000]	train-auc:0.97149	valid-auc:0.96130
# [1100]	train-auc:0.97235	valid-auc:0.96145
# [1200]	train-auc:0.97317	valid-auc:0.96157
# [1300]	train-auc:0.97393	valid-auc:0.96167
# [1400]	train-auc:0.97458	valid-auc:0.96175
# [1500]	train-auc:0.97528	valid-auc:0.96182
# [1600]	train-auc:0.97595	valid-auc:0.96190
# [1700]	train-auc:0.97656	valid-auc:0.96196
# [1800]	train-auc:0.97719	valid-auc:0.96200
# [1900]	train-auc:0.97781	valid-auc:0.96206
# [2000]	train-auc:0.97837	valid-auc:0.96209
# [2100]	train-auc:0.97893	valid-auc:0.96212
# [2200]	train-auc:0.97948	valid-auc:0.96216
# [2300]	train-auc:0.98000	valid-auc:0.96219
# [2400]	train-auc:0.98050	valid-auc:0.96222
# [2500]	train-auc:0.98101	valid-auc:0.96224
# [2600]	train-auc:0.98152	valid-auc:0.96227
# [2700]	train-auc:0.98199	valid-auc:0.96229
# [2800]	train-auc:0.98248	valid-auc:0.96230
# [2900]	train-auc:0.98293	valid-auc:0.96231
# [3000]	train-auc:0.98337	valid-auc:0.96233
# [3100]	train-auc:0.98383	valid-auc:0.96233
# [3200]	train-auc:0.98426	valid-auc:0.96235
# [3300]	train-auc:0.98472	valid-auc:0.96235
# [3313]	train-auc:0.98477	valid-auc:0.96235
# Kaggle Metric = 0.795135383901441
#
# #########################
# ### SEED 43
# ### Fold 4
# ### Train size 367131 Valid size 91782
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93896	valid-auc:0.93854
# [100]	train-auc:0.95669	valid-auc:0.95446
# [200]	train-auc:0.95993	valid-auc:0.95678
# [300]	train-auc:0.96227	valid-auc:0.95832
# [400]	train-auc:0.96413	valid-auc:0.95938
# [500]	train-auc:0.96580	valid-auc:0.96017
# [600]	train-auc:0.96722	valid-auc:0.96070
# [700]	train-auc:0.96842	valid-auc:0.96107
# [800]	train-auc:0.96951	valid-auc:0.96136
# [900]	train-auc:0.97050	valid-auc:0.96158
# [1000]	train-auc:0.97140	valid-auc:0.96176
# [1100]	train-auc:0.97226	valid-auc:0.96190
# [1200]	train-auc:0.97304	valid-auc:0.96202
# [1300]	train-auc:0.97383	valid-auc:0.96213
# [1400]	train-auc:0.97453	valid-auc:0.96220
# [1500]	train-auc:0.97523	valid-auc:0.96229
# [1600]	train-auc:0.97590	valid-auc:0.96234
# [1700]	train-auc:0.97654	valid-auc:0.96239
# [1800]	train-auc:0.97713	valid-auc:0.96244
# [1900]	train-auc:0.97771	valid-auc:0.96248
# [2000]	train-auc:0.97833	valid-auc:0.96252
# [2100]	train-auc:0.97887	valid-auc:0.96256
# [2200]	train-auc:0.97943	valid-auc:0.96259
# [2300]	train-auc:0.97996	valid-auc:0.96262
# [2400]	train-auc:0.98048	valid-auc:0.96265
# [2500]	train-auc:0.98097	valid-auc:0.96266
# [2600]	train-auc:0.98146	valid-auc:0.96268
# [2700]	train-auc:0.98196	valid-auc:0.96270
# [2800]	train-auc:0.98247	valid-auc:0.96272
# [2900]	train-auc:0.98292	valid-auc:0.96274
# [3000]	train-auc:0.98341	valid-auc:0.96276
# [3100]	train-auc:0.98385	valid-auc:0.96277
# [3200]	train-auc:0.98427	valid-auc:0.96277
# [3300]	train-auc:0.98468	valid-auc:0.96278
# [3400]	train-auc:0.98510	valid-auc:0.96280
# [3500]	train-auc:0.98552	valid-auc:0.96281
# [3600]	train-auc:0.98593	valid-auc:0.96282
# [3700]	train-auc:0.98632	valid-auc:0.96282
# [3800]	train-auc:0.98670	valid-auc:0.96283
# [3880]	train-auc:0.98700	valid-auc:0.96282
# Kaggle Metric = 0.799068198815457
#
# #########################
# ### SEED 43
# ### Fold 5
# ### Train size 367131 Valid size 91782
# ### Training with 100% fold data...
# #########################
# [0]	train-auc:0.93900	valid-auc:0.93886
# [100]	train-auc:0.95665	valid-auc:0.95499
# [200]	train-auc:0.95980	valid-auc:0.95734
# [300]	train-auc:0.96216	valid-auc:0.95890
# [400]	train-auc:0.96404	valid-auc:0.95999
# [500]	train-auc:0.96572	valid-auc:0.96071
# [600]	train-auc:0.96716	valid-auc:0.96121
# [700]	train-auc:0.96835	valid-auc:0.96157
# [800]	train-auc:0.96944	valid-auc:0.96186
# [900]	train-auc:0.97043	valid-auc:0.96206
# [1000]	train-auc:0.97132	valid-auc:0.96223
# [1100]	train-auc:0.97218	valid-auc:0.96237
# [1200]	train-auc:0.97298	valid-auc:0.96248
# [1300]	train-auc:0.97372	valid-auc:0.96257
# [1400]	train-auc:0.97445	valid-auc:0.96264
# [1500]	train-auc:0.97518	valid-auc:0.96271
# [1600]	train-auc:0.97587	valid-auc:0.96280
# [1700]	train-auc:0.97650	valid-auc:0.96285
# [1800]	train-auc:0.97712	valid-auc:0.96291
# [1900]	train-auc:0.97771	valid-auc:0.96296
# [2000]	train-auc:0.97831	valid-auc:0.96300
# [2100]	train-auc:0.97890	valid-auc:0.96304
# [2200]	train-auc:0.97946	valid-auc:0.96309
# [2300]	train-auc:0.98001	valid-auc:0.96311
# [2400]	train-auc:0.98055	valid-auc:0.96313
# [2500]	train-auc:0.98104	valid-auc:0.96315
# [2600]	train-auc:0.98154	valid-auc:0.96318
# [2700]	train-auc:0.98203	valid-auc:0.96320
# [2800]	train-auc:0.98250	valid-auc:0.96322
# [2900]	train-auc:0.98299	valid-auc:0.96323
# [3000]	train-auc:0.98343	valid-auc:0.96326
# [3100]	train-auc:0.98386	valid-auc:0.96328
# [3200]	train-auc:0.98432	valid-auc:0.96330
# [3300]	train-auc:0.98477	valid-auc:0.96331
# [3400]	train-auc:0.98519	valid-auc:0.96331
# [3500]	train-auc:0.98561	valid-auc:0.96333
# [3600]	train-auc:0.98601	valid-auc:0.96334
# [3700]	train-auc:0.98640	valid-auc:0.96336
# [3800]	train-auc:0.98677	valid-auc:0.96336
# [3900]	train-auc:0.98715	valid-auc:0.96338
# [4000]	train-auc:0.98752	valid-auc:0.96338
# [4100]	train-auc:0.98789	valid-auc:0.96339
# [4200]	train-auc:0.98824	valid-auc:0.96339
# [4300]	train-auc:0.98858	valid-auc:0.96340
# [4400]	train-auc:0.98893	valid-auc:0.96341
# [4500]	train-auc:0.98924	valid-auc:0.96342
# [4571]	train-auc:0.98947	valid-auc:0.96341
# Kaggle Metric = 0.7960644225495905
#
# #########################
# OVERALL CV Kaggle Metric = 0.7979803094946979

# %%
oof
# Out:
# array([ 1.15419364, -7.93937588, -6.1991326 , ...,  2.27935576,
#        -4.61087211,  2.17345047])

# %%
oof = pd.DataFrame({'customer_ID':train.customer_ID,'target':train.target,'oof_pred':oof})
oof = oof.set_index('customer_ID')
oof.to_csv('oof_transfer_learning.csv',index=False)
